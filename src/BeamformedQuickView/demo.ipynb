# %%
import numpy as np
import matplotlib.pyplot as plt
from lofarSun.lofarData import LofarDataBF

# %%
lofar_bf = LofarDataBF()
# load data
lofar_bf.load_sav("E:\\nextcloud\\meeting\\nacad\\2019_aut\\Lofar_spike\\data\\L599747_20170712_084137_short_data.sav")

# %%
# interpolate X,Y to get a beamform image
[X,Y,data_bf,x,y,Ibeam] = lofar_bf.bf_image_by_idx(30,100)

# plot
plt.imshow(data_bf, cmap='gist_heat',origin='lower',
                 extent=[np.min(X),np.max(X),np.min(Y),np.max(Y)])
plt.show()

# %%
bf_res,bf_err = lofar_bf.bf_fit_gauss_source_by_idx(30,100)
print(bf_res)
print(bf_err)
# Out:
# [50.05817922 56.2927238  63.12254158 40.9817908  45.80303234 60.1479996
#  50.58649633 36.02291499 43.10735366 41.35873715]
# (58, 800, 215)
# (58, 800, 215)
# {'s0': 65.43723955445212, 'x_cent': -171.49582979342216, 'y_cent': -721.4920526291916, 'tile': 2.325420690616189, 'x_sig': 592.5638059512457, 'y_sig': 474.9951314946505}
# {'s0': 2.55268092503984, 'x_cent': 180.73840482978972, 'y_cent': 275.2123502572574, 'tile': 0.022081158808191146, 'x_sig': 915.2901520877399, 'y_sig': 792.6010795396085}

# %%
# write the bfcube into fits:
lofar_bf.write_fits_full('.','test2.fits')
